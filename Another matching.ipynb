# %% [markdown]
# # Setting up

# %%
import os
import pandas as pd
import numpy as np
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import re
import nltk
import pymorphy2
from tqdm import tqdm

# %%
files = os.listdir('IT')

# %%
vacancies_it = pd.DataFrame()

for file in files:
    sub_category_name = file.split('.csv')[0]
    
    sub_category_df = pd.read_csv('IT/' +file, index_col=0)
    
    sub_category_df['SUBCATEGORY'] = sub_category_name
    
    vacancies_it = pd.concat([vacancies_it, sub_category_df], ignore_index=True)

# %%
vacancies_it.head()
# Out:
#                                            Название  \
# 0                     Программист-разработчик (SQL)
# 1                              Программист C#/ .NET
# 2                       Системный и Бизнес-аналитик
# 3  Руководитель проекта (разработка и внедрение ПО)
# 4                                    Java Team lead
#
#                         Компания  \
# 0  ООО Финансово-правовой альянс
# 1    ООО Syntellect (Синтеллект)
# 2                         Fortis
# 3                          Наука
# 4                          Наука
#
#                                       Местоположение  \
# 0  Сенная площадь, Санкт-Петербург, улица Ефимова...
# 1                                    Санкт-Петербург
# 2       Звёздная, Санкт-Петербург, Звёздная улица, 1
# 3  Политехническая, Санкт-Петербург, Гжатская ули...
# 4  Политехническая, Санкт-Петербург, Гжатская ули...
#
#                             Занятость  \
# 0       Полная занятость, полный день
# 1  Полная занятость, удаленная работа
# 2       Полная занятость, полный день
# 3       Полная занятость, полный день
# 4       Полная занятость, полный день
#
#                                Требования по умениям Требования по опыту  \
# 0                                                NaN             3–6 лет
# 1   Опыт работы с WPF Опыт в автоматизации задач ...            1–3 года
# 2                                                NaN            1–3 года
# 3                                                NaN             3–6 лет
# 4                                                NaN        не требуется
#
#                              Должностные обязанности  \
# 0   Разработка и внедрение ПО, охватывающего весь...
# 1   Высшее\неполное высшее образование в сфере ИТ...
# 2
# 3
# 4
#
#                                       Зарплата  \
# 0                      до 300 000 руб. на руки
# 1  от 60 000 до 150 000 руб. до вычета налогов
# 2                               з/п не указана
# 3                       от 90 000 руб. на руки
# 4                               з/п не указана
#
#                                      Ключевые навыки  \
# 0  Базы данных, Анализ данных, SQL, Разработка ПО...
# 1  C#, Transact-SQL, SQL, MS SQL, .NET Framework,...
# 2
# 3  MS Project, Управление проектами, Управление р...
# 4
#
#                              SUBCATEGORY
# 0  системы управления предприятием (erp)
# 1  системы управления предприятием (erp)
# 2  системы управления предприятием (erp)
# 3  системы управления предприятием (erp)
# 4  системы управления предприятием (erp)

# %% [markdown]
# # Preparing vacancies data set

# %%
vacancies_it['Ключевые навыки'] = vacancies_it['Ключевые навыки'].apply(lambda x: re.sub(',', '.', x))

# %%
vacancies_it = vacancies_it.fillna(' ')

# %%
vacancies_it_with_rs = vacancies_it.copy()

# %%
vacancies_it_with_rs['REQ+SKILLS'] = vacancies_it['Ключевые навыки'] + ' ' + vacancies_it['Требования по умениям']

# %%
vacancies_it_with_rs['REQ+SKILLS'] = vacancies_it_with_rs['REQ+SKILLS'].apply(lambda x : re.sub(r'\s+', ' ', x))

# %%
vacancies_it_with_rs = vacancies_it_with_rs[vacancies_it_with_rs['REQ+SKILLS'] != ' ']

# %%
vacancies_it_with_rs = vacancies_it_with_rs.drop(['Должностные обязанности', 'Ключевые навыки', 'Требования по умениям'], axis=1)

# %%
vacancies_it_with_rs.head()
# Out:
#                                            Название  \
# 0                     Программист-разработчик (SQL)
# 1                              Программист C#/ .NET
# 3  Руководитель проекта (разработка и внедрение ПО)
# 5                                    Программист 1С
# 6                           Программист PHP Битрикс
#
#                         Компания  \
# 0  ООО Финансово-правовой альянс
# 1    ООО Syntellect (Синтеллект)
# 3                          Наука
# 5                         Неркон
# 6                    ООО Вебдока
#
#                                       Местоположение  \
# 0  Сенная площадь, Санкт-Петербург, улица Ефимова...
# 1                                    Санкт-Петербург
# 3  Политехническая, Санкт-Петербург, Гжатская ули...
# 5        Санкт-Петербург, Площадь Ленина, Выборгская
# 6  Площадь Ленина, Санкт-Петербург, Кондратьевски...
#
#                             Занятость Требования по опыту  \
# 0       Полная занятость, полный день             3–6 лет
# 1  Полная занятость, удаленная работа            1–3 года
# 3       Полная занятость, полный день             3–6 лет
# 5  Полная занятость, удаленная работа         более 6 лет
# 6  Полная занятость, удаленная работа             3–6 лет
#
#                                       Зарплата  \
# 0                      до 300 000 руб. на руки
# 1  от 60 000 до 150 000 руб. до вычета налогов
# 3                       от 90 000 руб. на руки
# 5             от 25 000 до 45 000 руб. на руки
# 6            от 60 000 до 110 000 руб. на руки
#
#                              SUBCATEGORY  \
# 0  системы управления предприятием (erp)
# 1  системы управления предприятием (erp)
# 3  системы управления предприятием (erp)
# 5  системы управления предприятием (erp)
# 6  системы управления предприятием (erp)
#
#                                           REQ+SKILLS
# 0  Базы данных. Анализ данных. SQL. Разработка ПО...
# 1  C#. Transact-SQL. SQL. MS SQL. .NET Framework....
# 3  MS Project. Управление проектами. Управление р...
# 5  1С программирование. 1С: Управление Торговлей....
# 6                     битрикс. bitrix. yii. symfony

# %%
re.split(r'[.;]', vacancies_it_with_rs['REQ+SKILLS'].iloc[5])
# Out:
# ['ERP-системы на базе 1С',
#  ' ERP Опыт внедрения 1С: ERP на производственном предприятии обязателен',
#  ' Опыт внедрения 1С:ERP на предприятии с количеством пользователей от 20 человек обязательно',
#  ' Сертификат, подтверждающий квалификацию от 1С',
#  ' Рекомендации и(или) портфолио успешных проектов внедрения',
#  ' ']

# %%
vacancies_it_with_rs['SKILLS_SPLIT'] = vacancies_it_with_rs['REQ+SKILLS'].apply(lambda x : [word.strip() for word in re.split(r'[.;]', x)])

# %%
vacancies_it_with_rs.head()
# Out:
#                                            Название  \
# 0                     Программист-разработчик (SQL)
# 1                              Программист C#/ .NET
# 3  Руководитель проекта (разработка и внедрение ПО)
# 5                                    Программист 1С
# 6                           Программист PHP Битрикс
#
#                         Компания  \
# 0  ООО Финансово-правовой альянс
# 1    ООО Syntellect (Синтеллект)
# 3                          Наука
# 5                         Неркон
# 6                    ООО Вебдока
#
#                                       Местоположение  \
# 0  Сенная площадь, Санкт-Петербург, улица Ефимова...
# 1                                    Санкт-Петербург
# 3  Политехническая, Санкт-Петербург, Гжатская ули...
# 5        Санкт-Петербург, Площадь Ленина, Выборгская
# 6  Площадь Ленина, Санкт-Петербург, Кондратьевски...
#
#                             Занятость Требования по опыту  \
# 0       Полная занятость, полный день             3–6 лет
# 1  Полная занятость, удаленная работа            1–3 года
# 3       Полная занятость, полный день             3–6 лет
# 5  Полная занятость, удаленная работа         более 6 лет
# 6  Полная занятость, удаленная работа             3–6 лет
#
#                                       Зарплата  \
# 0                      до 300 000 руб. на руки
# 1  от 60 000 до 150 000 руб. до вычета налогов
# 3                       от 90 000 руб. на руки
# 5             от 25 000 до 45 000 руб. на руки
# 6            от 60 000 до 110 000 руб. на руки
#
#                              SUBCATEGORY  \
# 0  системы управления предприятием (erp)
# 1  системы управления предприятием (erp)
# 3  системы управления предприятием (erp)
# 5  системы управления предприятием (erp)
# 6  системы управления предприятием (erp)
#
#                                           REQ+SKILLS  \
# 0  Базы данных. Анализ данных. SQL. Разработка ПО...
# 1  C#. Transact-SQL. SQL. MS SQL. .NET Framework....
# 3  MS Project. Управление проектами. Управление р...
# 5  1С программирование. 1С: Управление Торговлей....
# 6                     битрикс. bitrix. yii. symfony
#
#                                         SKILLS_SPLIT
# 0  [Базы данных, Анализ данных, SQL, Разработка П...
# 1  [C#, Transact-SQL, SQL, MS SQL, , NET Framewor...
# 3  [MS Project, Управление проектами, Управление ...
# 5  [1С программирование, 1С: Управление Торговлей...
# 6                    [битрикс, bitrix, yii, symfony]

# %% [markdown]
# # Getting full lists of key words for each vacancy

# %%
full_skills = vacancies_it_with_rs.groupby('SUBCATEGORY')['SKILLS_SPLIT'].sum()

# %%
stop_words = nltk.corpus.stopwords.words('russian') + nltk.corpus.stopwords.words('english')

# %%
for category in full_skills.index:
    full_skills[category] = [phrase.lower() for phrase in full_skills[category]]
    full_skills[category] = [re.sub(r'[—;–/\\,.:\+()«»]', ' ', phrase) for phrase in full_skills[category]]
    full_skills[category] = [re.sub(r'\b\d+\b', ' ', phrase) for phrase in full_skills[category]]
    full_skills[category] = [re.sub(r'-\w+', ' ', phrase) for phrase in full_skills[category]]
    full_skills[category] = [re.sub(r'\b\w\b', ' ', phrase) for phrase in full_skills[category]]
    full_skills[category] = [re.sub(r'\s+', ' ', phrase) for phrase in full_skills[category]]
    
    for stop_word in stop_words:
        full_skills[category] = [re.sub('\b' + stop_word + '\b', '', phrase) for phrase in full_skills[category]]
    
    full_skills[category] = [phrase.strip() for phrase in full_skills[category] if phrase.strip() != '' and phrase.strip() != '#'
                            and phrase.strip() != '-']

# %%
full_skills
# Out:
# SUBCATEGORY
# crm системы                              [1с, битрикс24, crm, управление отношениями кл...
# cto, cio, директор по it                 [apache http server, руководство коллективом, ...
# web инженер                              [английский a1 начальный, django framework, gi...
# web мастер                               [английский a1 начальный, django framework, gi...
# администратор баз данных                 [1с программирование, обновление конфигурации ...
# аналитик                                 [linux, биоинформатика опыт работы ngs данными...
# банковское по                            [базы данных, анализ данных, sql, разработка п...
# инженер                                  [linux, ansible, clickhouse, cassandra, git, l...
# интернет                                 [работа команде, точность внимательность детал...
# маркетинг                                [бизнес, английский язык, ms visio, разработка...
# поддержка, helpdesk                      [apache http server, руководство коллективом, ...
# программирование, разработка             [законченно высшее техническое, отличные навык...
# продажи                                  [ведение переговоров, управление проектами, по...
# сетевые технологии                       [управление рисками, управление проектами, опт...
# системная интеграция                     [базы данных, анализ данных, sql, разработка п...
# системный администратор                  [apache http server, руководство коллективом, ...
# системы управления предприятием (erp)    [базы данных, анализ данных, sql, разработка п...
# телекоммуникации                         [java, android, kotlin, ооп, git, android sdk,...
# тестирование                             [java, python, docker, test automation, qa, ja...
# управление проектами                     [управление рисками, управление проектами, опт...
# Name: SKILLS_SPLIT, dtype: object

# %%
full_skills['crm системы']
# Out:
# ['1с',
#  'битрикс24',
#  'crm',
#  'управление отношениями клиентами',
#  'автоматизация',
#  'управление процессами',
#  'деловая коммуникация',
#  'обучение развитие',
#  'ведение переговоров испытательный срок месяца',
#  'оформление по тк рф',
#  'зарплата формируется по итогам собеседования зависимости от вашего опыта компетенций',
#  'английский b1 средний',
#  'ios',
#  'android',
#  'flutter',
#  'dart',
#  'sqlite',
#  'rest',
#  'бухгалтерский учет',
#  '1с управление торговлей',
#  '1с предприятие',
#  '1с комплексная автоматизация',
#  'банк',
#  '1с программирование',
#  '1с бухгалтерия',
#  'налоговая отчетность',
#  'бухгалтерская отчетность',
#  'основные средства',
#  'тмц',
#  'годовой баланс',
#  'расчет ндс',
#  'отчет прибылях убытках',
#  'прохождение налоговых проверок',
#  'реализация товаров услуг',
#  'расчет затрат обязательно знание бухгалтерского учета опыт работы самостоятельной развертки настройки 1c предприятие конфигурации бух ут ка erp опыт развертки обновления конфигураций программных продуктов 1с опыт или желание обучиться изменениях документов конфигурации настройках прав пользователей желание поддерживать знания актуальном состоянии развиваться уверенные знания ос windows включая основные серверные роли - ваше преимущество',
#  '1с управление производственным предприятием',
#  '1с бухгалтерия',
#  '1с управление торговлей',
#  '1с программирование график работы',
#  'до',
#  'корпоративная развозка от до',
#  'новочеркасская компенсация обедов оплата % от стоимости дмс',
#  '1с программирование',
#  '1с управление торговлей',
#  '1с crm проф',
#  'sap crm',
#  'базы данных',
#  'субд',
#  'erp на базе 1с',
#  'cистемы управления базами данных',
#  '1c бухгалтерия',
#  '1с предприятие',
#  '1с торговля',
#  '1с предприятие',
#  '1с управление предприятием',
#  'crm',
#  'системное мышление',
#  'информационные технологии',
#  'обновление конфигурации 1с',
#  'бухгалтерский учет',
#  'управленческий учет',
#  'erp',
#  'sap',
#  'автоматизация документооборота',
#  '1с документооборот',
#  'битрикс',
#  'bitrix',
#  'yii',
#  'symfony',
#  'трудоустройство соответствии тк рф',
#  'заработная плата оклад премия kpi',
#  'испытательный срок месяца',
#  'дмс со стоматологией после прохождения испытательного срока',
#  'офис собственном здании районе',
#  'бухарестская',
#  'график работы сменный до часовая рабочая смена',
#  'возможность профессионального карьерного роста внутри компании',
#  'опыт программирования на',
#  'от лет',
#  'опыт сопровождения доработки конфигурации 1с управление торговлей взаимоотношениями клиентами crm редакция',
#  '1с crm',
#  'опыт настройки бп 1с crm',
#  'опыт интеграции 1с сайтом',
#  'опыт работы пользователями консультирование разработка анализ задач',
#  'уверенные знания механизмов платформы средств разработки 1с',
#  'умение разбираться чужом коде',
#  'самостоятельность ответственность коммуникабельность доброжелательность исполнительность',
#  'знание типовых конфигураций 1с управление торговлей склад',
#  'бухгалтерия зуп crm наличие сертификатов 1с - будет являться преимуществом для кандидата',
#  'знание 1с ут',
#  'опыт разработки процедур обмена данными',
#  'sql',
#  'javascript',
#  'asp',
#  'net',
#  'entity framework',
#  'less',
#  'terrasoft crm желание обучаться нацеленность на развитие самостоятельность готовность работать команде опыт программирования javascript # работы бд mssql готовность работать во внештатном режиме когда это действительно надо соответствующими бонусами но не на износ - вы нужны нам живые здоровые',
#  'ооп',
#  'javascript',
#  'html',
#  'aura',
#  'apex',
#  'lwc',
#  'salesforce',
#  'моделирование бизнес процессов',
#  'битрикс',
#  'php',
#  'mysql',
#  'управление проектами',
#  'oracle',
#  'oracle pl sql',
#  'delphi',
#  'английский b2 средне',
#  'google analytics',
#  'seo',
#  'маркетинговые коммуникации',
#  'маркетинговый анализ',
#  'internet marketing',
#  'google adwords',
#  'медиапланирование',
#  'управление маркетингом',
#  'яндекс',
#  'метрика',
#  'яндекс',
#  'директ',
#  'контекстная реклама',
#  'развитие продаж',
#  'интернет',
#  'b2b маркетинг',
#  'smm',
#  'разработка маркетинговой стратегии',
#  'анализ рынка',
#  'продвижение сайтов',
#  'digital marketing',
#  'интернет маркетинг опыт работы digital маркетинге не менее лет обязательно',
#  'опыт создания реализации маркетинговой стратегии медиапланов обязательно',
#  'умение работать инструментами для привлечения платного трафика',
#  'наличие доказанного успешного опыт работы facebook ads google ads яндекс',
#  'директ mytarget youtube cpa другими инструментами',
#  'знание понимание основных метрик cpm cpc cpa cpl cps ctr cr romi roas понимание как на них можно повлиять умение это делать',
#  'наличие практических знаний работы системах аналитики яндекс метрика google analytics наличие соответствующей сертификации желательно',
#  'знание систем сквозной аналитики умение интерпретировать применять полученные данные также уверенно владеть другими инструментами для работы аудиториями',
#  'умение строить воронки продаж влиять на конверсию между этапами помощью инструментов digital маркетинга',
#  'умение работать автономно принимать операционные решения самостоятельно',
#  'проявление личной инициативы хорошо развитые коммуникативные навыки',
#  'ответственность за результат принятые решение личная организованность',
#  'желание постоянно обучаться расти как профессионалу',
#  'дисциплинированность исполнительность',
#  'умение доводить до результата полученные задачи придуманные идеи',
#  'развитый навык мыслить масштабно не останавливаться на достигнутом',
#  'письменный устный английский на уровне upper intermediate выше',
#  'чувство юмора позитивный настрой must have',
#  'php',
#  'jquery',
#  'css',
#  'html',
#  'css3',
#  '1с',
#  'git',
#  'json api',
#  'базы данных',
#  'unit testing',
#  'битрикс24',
#  'mysql',
#  'ооп',
#  'php7',
#  'битрикс24',
#  '1с',
#  'работа команде',
#  'crm',
#  'пользователь пк',
#  'работа базами данных',
#  'php',
#  'mysql опыт работы bitrix framework',
#  'знание продуктов 1с',
#  'владение основами работы js rest api',
#  'аналитические исследования',
#  'ms visio',
#  'работа системами аналитики',
#  'отчетность',
#  'системный подход',
#  'аналитическое мышление',
#  'развитие сайта',
#  'разработка новых сервисов',
#  'agile project management',
#  'project management',
#  'управление процессами',
#  'управление командой',
#  'руководство коллективом',
#  'ориентация на результат опыт участия коммерческой разработке качестве рм желательно на стыке po не менее лет',
#  'сертификация pmi желательно использование современных методологий agile предыдущих проектах',
#  'наличие технического бэкграунда обязательно',
#  'понимание принципов основных циклов разработки процесса разработки использованием js node',
#  'js react postgresql sphinx html css',
#  'знание современных cms опыт работы ними',
#  'умение анализировать продуктовые бизнес метрики',
#  'навык быстро погрузиться детали продукта процессов отдельно делать системный анализ',
#  'умение формировать тз прототипы продукта user story',
#  'опыт построения продуктов процессов нуля умение найти подход эффективно взаимодействовать разными отделами подрядчиками распределенными командами',
#  'умение одновременно поддерживать старые проекты разрабатывать новые',
#  'письменный устный английский на уровне upper intermediate выше',
#  'чувство юмора позитивный настрой must have',
#  '1с управление предприятием программирование на управляемых обычных формах',
#  'знание скд конвертации данных веб',
#  'наличие сертификатов 1с специалист будет преимуществом',
#  'английский b1 средний',
#  'javascript',
#  'mysql',
#  'linux',
#  'yii',
#  'git',
#  'php',
#  'sql хорошие знания php',
#  'именно современного php phptherightway',
#  'понимание что такое очередь зачем она нужна опыт redis будет умение спроектировать базу mysql нормализация индексы',
#  'навыки работы linux настройка служб работа консоли желание разобраться golang понимание rest api желание обучаться',
#  'английский b2 средне',
#  'angularjs',
#  'javascript',
#  'bootstrap',
#  'mysql',
#  'node',
#  'js',
#  'php5',
#  'css',
#  'yii',
#  'ajax',
#  '1с программирование',
#  '1c бухгалтерия',
#  '1с предприятие',
#  '1с бухгалтерия',
#  'бухгалтерский учет высшее техническое образование',
#  'уверенное программирование 1c',
#  'понимание принципов бухгалтерского управленческого учета',
#  'знание обмена между конфигурациями',
#  'опыт работы от лет',
#  'знание 1с 1с',
#  '1с предприятие',
#  '1с розница',
#  '1с документооборот',
#  '1с предприятие',
#  '1с бухгалтерия',
#  '1с управление торговлей',
#  '1с предприятие',
#  '1c бухгалтерия',
#  '1с программирование',
#  '1с торговля склад',
#  '1с зарплата управление персоналом',
#  'интернет',
#  'креативность',
#  'яндекс',
#  'директ',
#  'google analytics',
#  'yandex direct',
#  'google adwords',
#  'яндекс',
#  'метрика',
#  'internet marketing',
#  'b2b продажи',
#  'планирование рекламных кампаний',
#  'smo',
#  'sms маркетинг',
#  'smm',
#  'seo оптимизация',
#  'лидогенерация',
#  'составление семантического ядра',
#  '1с программирование',
#  'erp на базе 1с',
#  'erp',
#  'аналитическое мышление',
#  '1с предприятие',
#  '1с зарплата управление персоналом опыт работы аналогичной должности от двух лет отличное знание платформы 1с высшее образование аналитические способности ответственность внимательность коммуникабельность',
#  '1с предприятие',
#  '1с управление торговлей',
#  'бизнес',
#  'описание бизнес',
#  'настройка crm',
#  'организаторские навыки',
#  'моделирование бизнес процессов',
#  'оптимизация бизнес',
#  'системный анализ',
#  'аналитическое мышление',
#  'бизнес',
#  'статистический анализ',
#  'бизнес',
#  'управленческая отчетность',
#  'постановка задач разработчикам',
#  '1с комплексная автоматизация',
#  'jquery',
#  'sass',
#  'javascript',
#  'git',
#  'css опыт разработки на 1c битрикс бус ред',
#  'бизнес от лет',
#  'понимание архитектуры битрикс знание стандартных классов',
#  'опыт работы ядром d7 том числе orm',
#  'опыт разработки компонентов модулей',
#  'понимание принципов работы стандартного кеша композита',
#  'понимание технологий интеграции между платформами api триггеры вебхуки',
#  'опыт работы git',
#  'хорошее знание html css js jquery без верстки соблюдение codestyle',
#  'плюсом будет разработка frontend не верстка - npm webpack js sass scss pug знание опыт bem',
#  'высшее образование области информационных технологий',
#  'стаж работы не менее года данном направлении',
#  'умение писать sql',
#  'знания платформы crm terrasoft creatio будет является преимуществом',
#  'опыт работы crm или банковскими системами- желательно',
#  'ответственность исполнительность целеустремленность обучаемость умение работать режиме многозадачности',
#  'microsoft dynamics crm',
#  'ms dynamics crm',
#  'ms sharepoint',
#  'консультирование',
#  'crm опыт настройки системного программного обеспечения os sql опыт настройки бизнес dynamics 1c др',
#  'понимание процессов проектирования разработки по навык разработки рабочих документов регламентов инструкций проектной документации мы готовы рассматривать специалистов небольшим опытом желающих развиваться данном направлении',
#  'разработка технических заданий',
#  'ms visio',
#  'функциональное тестирование',
#  'sql',
#  'тестирование',
#  '1с предприятие',
#  '1с торговля',
#  '1c бухгалтерия',
#  '1с документооборот',
#  '1с программирование высшее техническое образование',
#  'знание конфигурации 1c управление производственным предприятием или 1с erp будет вашим преимуществом',
#  'умение писать нестандартные конфигурации',
#  'опыт коллективной разработки',
#  'windows forms',
#  'wpf',
#  'net framework',
#  'sql',
#  'аналогичный опыт - обязательно!',
#  'высокая степень самоорганизованности',
#  'atlassian jira',
#  'управление продуктом',
#  'аналитическое мышление',
#  'управление проектами',
#  'запуск новых продуктов',
#  'работа команде',
#  'разработка нового продукта',
#  'высшее техническое образование области информационных технологий',
#  'опыт разработки на javascript vue',
#  'js на уровне не ниже middle developer года',
#  'опыт работы команде разработчиков от года',
#  'опыт разработки автоматизированных рабочих мест на базе web',
#  'опыт разработки frontend- backend использованием vue',
#  'js',
#  'опыт работы инструментами ci cd понимание процесса разработки',
#  'опыт работы системами jira confluence',
#  'опыт работы по методологии agile',
#  'знания современных концепций технологий трендов развития программных продуктов',
#  'английский язык на уровне чтения технической литературы',
#  'crm',
#  'java',
#  'kotlin амбициозные цели',
#  'гибкий график',
#  'при необходимости есть возможность работать из дома',
#  'главное для нас - результат',
#  'неограниченные возможности для профессионального развития самореализации',
#  'топовое оборудование весь необходимый софт',
#  'официальное трудоустройство достойная полностью белая заработная плата',
#  'дмс компенсация мобильной связи занятий спортом языковых курсов покупки гаджетов',
#  'комфортный светлый офис кикером кофе йогуртами фруктами вкусными ужинами',
#  'насыщенная корпоративная жизнь',
#  'высшее образование опыт работы - лет знания sap bw bi is ds архитектура sap интеграция bw ролевая модель хорошие знания abap опыт работы sql pl tsql opensql hana sql script владение vba',
#  'crm',
#  'java',
#  'kotlin амбициозные цели',
#  'гибкий график',
#  'при необходимости есть возможность работать из дома',
#  'главное для нас - результат',
#  'неограниченные возможности для профессионального развития самореализации',
#  'топовое оборудование весь необходимый софт',
#  'официальное трудоустройство достойная полностью белая заработная плата',
#  'дмс компенсация мобильной связи занятий спортом языковых курсов покупки гаджетов',
#  'комфортный светлый офис кикером кофе йогуртами фруктами вкусными ужинами',
#  'насыщенная корпоративная жизнь',
#  'высшее техническое образование',
#  'опыт разработок на java от лет',
#  'знание принципов ооп',
#  'навык web react angular js',
#  'опыт разработки web приложений на языках asp',
#  'net core',
#  'js',
#  'опыт работы субд ms sql iis',
#  'желательны навыки php oracle mysql postgresql',
#  'ios',
#  'android',
#  'тестовая документация',
#  'testrail',
#  'jenkins',
#  'qa',
#  'тестирование',
#  'установка настройка нового оборудования поддержка существующего оборудования сервера массивы виртуализаторы распределенных данных системы резервного копирования защиты данных поддержка создание виртуальных систем на базе oracle ldom zones поддержка создание виртуальных систем на базе vmware esxi создание точек восстановления резервное копирование систем sap поддержка работоспособности систем sap устранение проблем улучшение производительности работы систем sap участие проектах дит',
#  'высшее образование',
#  'знание учёта на производственном предприятии',
#  'знание 1с erp',
#  '1с упп',
#  '1с пердприятие',
#  'знание 1с зуп crm до 1с pdm plm appius - желательно',
#  'курсовые сертификаты 1с будут дополнительным плюсом',
#  '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#  'javascript',
#  'less',
#  'jquery',
#  'css3',
#  'html5',
#  'vue опыт коммерческой разработки от лет',
#  'уверенное знание javascript jquery',
#  'уверенное знание vue',
#  'js vue router vuex',
#  'уверенные знания html кроссбраузерная адаптивная мобильная html5 css3 less',
#  'понимание основных принципов ui ux понимание принципов работы системе контроля версий',
#  'дополнительным плюсом будет опыт работы electron cordova node',
#  'js',
#  'sql уверенное знание языка #',
#  'net фреймворка',
#  'структуры данных linq entity framework паттерны проектирования',
#  'сервисы webapi wcf rest api',
#  'понимание механизмов аутентификации авторизации приложениях',
#  'опыт работы системами контроля версий',
#  'опыт работы sql сервером создание таблиц ключи связи написание запросов участием операторов join union',
#  'английский b2 средне',
#  'javascript',
#  'css',
#  'html',
#  'rest',
#  'sql',
#  '1с программирование',
#  '1с бухгалтерия',
#  '1с комплексная автоматизация',
#  'управление проектами',
#  'web ftp proxy bluecoat sg',
#  'soap',
#  'http',
#  'оптимизация бизнес',
#  'обучение персонала',
#  'обновление конфигурации 1с',
#  '1с документооборот',
#  'бухгалтерский учет знание платформы 1с управляемые формы скд веб- хттп- сервисы',
#  'знание библиотеки стандартных подсистем знание стандартов разработки конфигураций 1с умение работать конвертацией данных или начальные знания sql js php опыт работы от 3х лет',
#  'высшее образование области ит',
#  'желательно знания гибких методологий разработки',
#  'желательно опыт работы кроссфункциональных командах',
#  'опыт внедрения тестирования высоконагруженных систем',
#  'знание принципов построения реляционных nosql баз данных',
#  'опыт работы oracle postgresql tarantool couchbase mongodb mysql',
#  'опыт работы git gitlab artifactory jenkins построения процессов ci cd',
#  'знание принципов гипервизорной контейнерной виртуализации',
#  'опыт работы docker kubernetes rancher ansible',
#  'желательно опыт работы системами класса service registry service discovery consul etcd zookeeper',
#  'опыт работы nginx haproxy apache kafka rabbitmq',
#  'базовые знания скриптовых языков shell python',
#  'желателен опыт работы настройки нуля систем телеметрии grafana prometheus elastic search',
#  'знание linux red hat centos',
#  'на уровне администратора',
#  'английский на уровне чтения тех',
#  'документации',
#  'высшее среднее техническое образование',
#  'опыт работы бд ms sql уверенное владение sql опыт написания хранимых процедур',
#  'опыт работы ms windows server',
#  'опыт администрирования не менее лет понимание принципов работы 1с упп торговля склад умение работать большими объемами информации ответственность коммуникабельность стрессоустойчивость',
#  'высшее техническое образование',
#  'знание java java spring',
#  'знание принципов разработки веб',
#  'понимание mvc веб',
#  'опыт работы j2ee серверами приложений',
#  'опыт разработки веб soap rest',
#  'опыт работы субд oracle ms sql',
#  'знание принципов ооп',
#  'опыт использования npm git',
#  'понимание процесса ci cd',
#  'английский b2 средне',
#  'javascript',
#  'html',
#  'css',
#  'mysql',
#  'php',
#  'sql',
#  'laravel',
#  'symfony',
#  'wordpress',
#  'cms wordpress',
#  'опыт работы microsoft dynamics crm',
#  'опыт анализа описания оптимизации бизнес',
#  'опыт постановки технических заданий',
#  'опыт внедрения или сопровождения информационных систем от лет',
#  'опыт работы php от лет',
#  'обязателен опыт работы битрикс разработка внедрение функционала системы понимание автоматизируемых процессов том числе доработки стандартного функционала опыт работы ядром d7 новое ядро bitrix framework git понимание моделей рабочего процесса git flow github flow gitlab flow наличие портфолио',
#  'высшее среднее техническое образование',
#  'опыт работы по направлению области системного администрирования от лет',
#  'менеджер проектов',
#  'создание сайтов',
#  'управление интернет',
#  'управление проектами',
#  'составление технического задания',
#  'интернет магазины',
#  'техническая поддержка',
#  'проектный менеджмент',
#  'ведение переговоров',
#  'деловая переписка',
#  'joomla cms',
#  'cms wordpress',
#  'css',
#  'html',
#  'opencart',
#  '1с',
#  '1c',
#  '1с документооборот',
#  '1с бухгалтерия',
#  '1с зарплата управление персоналом',
#  '1с программирование',
#  '1с предприятие высшее образование',
#  'опыт работы от 2х лет',
#  'уверенное знание платформы',
#  'опыт разработки через хранилище конфигураций',
#  'опыт работы конвертацией данных',
#  'умение оптимизировать запросы читать чужой код',
#  'разработка сложных отчетов использованием скд',
#  'опыт работы логами graylog kibana пр',
#  'знание restapi',
#  'опыт работы технической поддержке линия',
#  'опыт работы команде',
#  'знание it администрирование linux windows принципы работы сетей передачи данных виртуальная инфраструктура задач мониторинга',
#  'опыт проектирования внедрения zabbix знание его архитектуры принципов работы',
#  'поддержка вендорских apm appdynamics',
#  'опыт разработки скриптов bash python powershell',
#  'опыт работы субд postgresql навыки написания sql',
#  'jquery',
#  '1с',
#  'git',
#  'javascript',
#  'php5',
#  'html',
#  'английский b1 средний',
#  'английский язык',
#  'грамотная речь',
#  'ms outlook',
#  'грамотность',
#  'работа большим объемом информации',
#  'ms excel',
#  'администрирование серверов',
#  'администрирование сетевого оборудования',
#  'информационная безопасность',
#  'настройка по',
#  'настройка почтовых серверов',
#  'настройка сетевых подключений',
#  'настройка пк финальный уровень заработной платы обсуждается успешным кандидатом индивидуально',
#  'официальное трудоустройство согласно тк рф',
#  'дмс после испытательного срока',
#  'график работы',
#  'корпоративная мобильная связь',
#  'профессиональный дружный коллектив',
#  'офис центре города',
#  'высшее образование области информационных технологий опыт работы данном направлении работы не менее года области опыт написания sql желателен опыт работы банковскими системами желателен опыт работы по сопровождению птк псд арм кбр',
#  'знания платформы цфт crm terrasoft является преимуществом ответственность целеустремленность опыт общения пользователями',
#  'понимание жизненного цикла разработки по',
#  'опыт тестировании по от',
#  'опыт работы jira redmine других баг системах системах управления проектами',
#  'опыт составления тест на основе bpmn use case текстового описания',
#  'понимание логики работы http',
#  'базовое знание языка запросов sql',
#  "делать выборки из бд простыми select'ами join'ами",
#  'высшее неполное высшее профессиональное образование',
#  'опыт работы качестве бизнес или системного аналитика от лет',
#  'опыт аналитики интеграционных задач',
#  'уверенное знание xml понимание основ проектирования rest интерфейсов микросервисной архитектуры приложений',
#  'знание sql на уровне написания сложных вложенных запросов',
#  'опыт работы финансовых организациях будет преимуществом',
#  'высшее техническое образование по профильной специальности',
#  'опыт разработки требований на прикладное программное обеспечение от лет',
#  'наличие навыков работы со средствами проектирования моделирования по',
#  'приветствуется умение читать программный код',
#  'приветствуется опыт проектирования olap кубов',
#  'уверенное программирование среде "1с предприятие"',
#  'не менее 2х лет управляемые формы желательно',
#  'навыки работы нетиповыми конфигурациями',
#  'умение четко грамотно излагать свои мысли документально при составлении технических заданий пользовательской технической документации описаний',
#  'высшее техническое образование',
#  'высшее техническое образование',
#  'опыт разработок на java от лет',
#  'знание принципов ооп',
#  'навык web react angular js',
#  'ооп',
#  'битрикс24',
#  'rest api',
#  'javascript',
#  '1с',
#  'mvc',
#  'настройка серверов apache реализация доработок битрикс24 crm согласно тз',
#  'доработка существующих решений',
#  'настройка администрирование битрикс24 crm',
#  'соблюдение сроков качества выполняемой работы',
#  'опыт работы от лет бизнес системным аналитиком',
#  'опыт разработки тз фт на доработку функциональности системы',
#  'знание sql субд',
#  '1с зарплата управление персоналом',
#  '1с предприятие',
#  '1с программирование',
#  '1с документооборот',
#  '1с бухгалтерия высшее образование по направлению подготовки информационных технологий',
#  'высшее образование бакалавриат магистратура маркетинг экономика математика',
#  'опытный пользователь excel обработка больших массивов данных опыт работы со сводными таблицами впр уверенное владение формулами',
#  'уверенное знание основных методов сегментации',
#  'способность работать режиме многозадачности',
#  'ответственность внимательность аналитический склад ума',
#  'опыт работы crm построением предиктивных моделей будет преимуществом',
#  'высшее техническое образование',
#  'знание java java spring',
#  'знание принципов разработки веб',
#  'понимание mvc веб',
#  'опыт работы j2ee серверами приложений',
#  'опыт разработки веб soap rest',
#  'опыт работы субд oracle ms sql',
#  'знание принципов ооп',
#  'опыт использования npm git',
#  'понимание процесса ci cd',
#  'образование высшее техническое желательно области ит',
#  'отличное знание системы microsoft dynamics ax',
#  'опыт работы аналитиком консультантом microsoft axapta от лет',
#  'опыт работы электронным документооборотом edi базовые знания xml',
#  'умение писать sql любой сложности',
#  'технический английский',
#  'желательно знание процессов розничной торговли',
#  'аналитический склад ума умение общаться пользователями стрессоустойчивость следование стандартам самостоятельность ответственность',
#  'английский a1 начальный',
#  '1с документооборот',
#  'erp на базе 1с',
#  '1c бухгалтерия',
#  '1с программирование',
#  'обновление конфигурации 1с',
#  '1с предприятие',
#  '1с управление производственным предприятием',
#  'storverk crm',
#  '1с производство',
#  'постановка задач разработчикам',
#  'crm опыт программирования storverk crm обязателен',
#  'приветствуется знания области бухгалтерии налогов финансовом планировании предприятия',
#  'профессиональное знание платформы 1с',
#  'упп erp',
#  'опыт крупных доработок типовых решений 1с или разработки конфигураций " нуля"',
#  'готовность рассказать существующие кейсы из личной практики результатами',
#  'sap erp',
#  'английский язык',
#  'sap',
#  'abap знание английского языка письменный обязательно устный',
#  'опыт программирования под модули fi сo sd mm pp',
#  'технологии написания печатных форм pdf smartforms',
#  'уверенное знание технологий sap enjoy controls abap objects',
#  'работа расширениями badi bdc bapi enhancements',
#  'навыки интеграции ms office excel word',
#  'высшее образование области информационных технологий',
#  'опыт администрирования поддержки hr',
#  'знание предметной области процессы управления персоналом кадровое администрирование расчет заработной платы налоговая отчетность',
#  'опыт работы sql или pl sql том числе написания запросов хранимых процедур пакетов',
#  'опыт работы босс будет являться преимуществом',
#  'желательно знание субд ms sql',
#  'qa',
#  'python',
#  'selenium ide',
#  'sql',
#  'jira',
#  'ms visual studio',
#  'tcp ip',
#  'английский язык',
#  'microsoft visual studio высшее среднее специальное по направлениям информатика вычислительная техника математика программирование программирование на языке среде ms visual stadio использованием stdlib mfc под oc windows общие принципы создания графических оконных пользовательских интерфейсов общие принципы сетевого взаимодействия стек tcp ip общие принципы работы последовательными каналами передачи данных rs- опыт работы ранними версиями среды разработки ms visual stadio начиная версии',
#  'соответствующими по времени стандартам языка библиотеками stdlib mfc навыки отладки по обратного проектирования реверс без необходимости дезассемблирования знание английского - разговорный',
#  'знания php html css mysql javascript',
#  'навык разработки компонентов бизнес 1с',
#  'опыт использования git',
#  '1c бухгалтерия',
#  '1c зарплата кадры',
#  '1с предприятие',
#  '1с программирование',
#  '1с управление торговлей',
#  'управляемые формы',
#  'sap hr',
#  'sap erp',
#  'sap',
#  'разработка технических заданий',
#  'разработка инструкций',
#  'опыт работы аналогичной должности от трех лет отличное знание платформы 1с высшее образование аналитические способности ответственность внимательность коммуникабельность',
#  'опыт аналогичной работы от лет высокие коммуникативные навыки',
#  'высшее образование ит программирование информатика автоматизация управление информационные системы опыт работы по специальности сфере разработки внедрения ис автоматизации бизнес предприятия желателен знание современных структурных языков программирования объектно программирование реляционные базы данных язык запросов web базовые знания предметных областях хотя бы кадровый бухгалтерский управленческий учет управление поставками запасами расчеты персоналом организация производства подготовка планирование производства знание oracle pl sql delphi object pascal ms office vba xml владение английским языком чтение перевод технический',
#  'sql',
#  'crm',
#  'математическая статистика',
#  'аналитические исследования',
#  'математический анализ',
#  'аналитика',
#  'анализ данных',
#  'postgresql',
#  'ms sql server',
#  'sql',
#  'ms visual studio',
#  'базы данных навыки проектирования бд проектирование структур хранения',
#  'навыки разработки серверного кода',
#  'опыт работы большими объемами данных оптимизация запросов планы статистика',
#  'базовые навыки администрирования windows',
#  'базовые навыки администрирования linux',
#  'базовые знания серверного железа',
#  'sql server опыт sql server выше от лет продуктах microsoft sql server management studio',
#  'уверенное владение запросы процедуры функции представления триггеры скрипты обновления',
#  'навыки администрирования бд ms sql бэкап рестор права линкованные сервера мониторинг диагностика',
#  'postgresql опыт postgresql выше от лет текущая версия под linux ubuntu debian',
#  'уверенное владение pl pgsql запросы функции триггеры представления скрипты обновления',
#  'навыки администрирования postgresql бэкап рестор обслуживание права foreign data wrappers отказоустойчивость репликация wal мониторинг диагностика',
#  'плюсом будет',
#  'активные продажи',
#  'b2b продажи',
#  'планирование продаж',
#  'телефонные переговоры',
#  'управление продажами',
#  'прямые продажи',
#  'навыки продаж',
#  '1с торговля',
#  'ведение переговоров',
#  'управление проектами',
#  'развитие продаж',
#  'навыки презентации',
#  'crm',
#  'знание основ функционирования бизнеса одной из отраслей - финансы экономические показатели налоги пр',
#  'знание или опыт работы sap опыт программирования 1с высшее образование желательно сфере ит финансов экономики широкий кругозор области ит опыт использования qlikview qlik sense',
#  '1с управление персоналом',
#  '1с управление предприятием',
#  '1с предприятие',
#  'планирование карьеры',
#  'angularjs',
#  'javascript',
#  'html',
#  'bootstrap',
#  'html5',
#  'опыт работы по направлению авторизация sap информационная безопасность sap - от лет',
#  'знание средств обеспечения контроля информационной безопасности решениях sap',
#  'понимание принципов разделения полномочий пользователей информационных системах sap матрица полномочий функциональные роли',
#  'общие теоретические знания области информационной безопасности',
#  'общее понимание процессов управления изменениями ведения проектов выполнения сервисных регламентных работ информационных системах sap',
#  'sap basis sap grc access control oracle idm hp service manager ms office',
#  'активные продажи',
#  'организаторские навыки',
#  'холодные звонки',
#  'работа возражениями',
#  'холодные продажи',
#  'crm',
#  'клиентоориентированность',
#  'поиск привлечение клиентов',
#  'телефонные переговоры',
#  'грамотная речь',
#  'прямые продажи',
#  'умение работать команде',
#  'многозадачность',
#  'сопровождение клиентов',
#  'работа команде',
#  'консультирование',
#  'высшее образование',
#  'знание стека технологий angularjs nodejs # ms excel уровень продвинутого пользователя написание формул sql - запросы для ms sql server',
#  'понимание принципов разделения полномочий пользователей информационных системах sap матрица полномочий функциональные роли',
#  'общие теоретические знания области информационной безопасности',
#  'общее понимание процессов управления изменениями ведения проектов выполнения сервисных регламентных работ информационных системах sap',
#  'опыт работы по направлению авторизация sap информационная безопасность sap - от лет',
#  'sap basis sap grc access control oracle idm hp service manager ms office',
#  'ms sql',
#  'ms sql server',
#  'английский язык',
#  'ms dynamics crm',
#  'биллинг',
#  'devops',
#  'ci cd',
#  'возможность дистанционной удаленной работы home office',
#  'компания предлагает стабильную интересную работу возможность профессионального развития',
#  'предоставление дополнительных отпусков',
#  'предоставление материальной помощи по особым случаям',
#  'добровольное медицинское страхование поликлиника стоматология - % компенсация для сотрудников компании',
#  'компенсация питания сотрудника',
#  'программа компенсаций занятий спортом',
#  'программа награждения сотрудников за выдающиеся успехи',
#  'опыт работы abap solman от года',
#  'владение английским или немецким - языком pre intermediate выше',
#  'проактивность ответственность',
#  'опыт работы sap abap от года',
#  'плюсом будет знания wf sap ui5 sap fiori',
#  'англ язык от pre или немецкий язык',
#  'разработка отчетов оптимизация программ',
#  'abap objects',
#  'bapi badi enhancement points spots userexits',
#  'smartforms pdf',
#  'приветствуется знание webdynpro ale pi xi adk',
#  'базовые знания одного или нескольких sap модулей',
#  'готовность развиваться ответственность умение работать команде',
#  '1с зарплата управление персоналом',
#  '1с зкгу',
#  '1с зуп',
#  'консультант 1с',
#  'высшее техническое образование',
#  'знание языков pl sql vb',
#  'знание учетного ядра основных банковских продуктов реализованных абс цфт',
#  'опыт разработки по на платформе цфт',
#  'умение выполнять оптимизацию sql',
#  'желателен опыт работы большими объемами данных',
#  '1с торговля',
#  '1с предприятие',
#  '1с бухгалтерия',
#  '1с программирование',
#  '1с управление торговлей',
#  'sql server',
#  '1с комплексная автоматизация знание опыт работы ут',
#  'бп',
#  'проф на профессиональном уровне',
#  'умение решать поставленные задачи стандартными способами 1с мимнимумом внешних обработок программирования',
#  'работа ут несколькими юрлицами опыт работы интеркампани опыт внедрения управленческого учета',
#  'опыт работы адресным складом понимание принципов crm воронки продаж опыт их внедрения',
#  'умение работать команде общаться коллегами бухгалтерами менеджерами складом руководством напрямую понимание их потребностей',
#  'знание sql server платформы 1с сервер предприятия',
#  'опыт работы переносом данных из разных конфигураций 1с',
#  'опыт настройки печатных форм ут',
#  'бп',
#  'проф',
#  'опыт настройки почтового сервиса ут',
#  'отчетность проделанной работе',
#  'понимание возможностей опыт работы одной из платформ для управления логистикой sap erp sap hana',
#  'желательно знание возможностей одной из платформ scm sap tms sap ewm',
#  'хорошее знание функциональной области управления логистикой',
#  'знание методов принципов подходов интеграции ит систем',
#  'опыт настройки поддержки модулей системе sap роли консультанта или старшего консультанта pp qm > лет',
#  'уровень владения английским языком не ниже intermediate',
#  'знание стандартных процессов sap pp qm',
#  'написание технических заданий проектных решений',
#  'умение читать abap программы простой сложности debugging будет плюсом',
#  'sql',
#  'oracle',
#  'ms sql server',
#  'ms sql',
#  'oracle 11g',
#  'crm',
#  'клиентоориентированность',
#  'интернет',
#  'работа команде',
#  'b2b продажи',
#  'навыки продаж',
#  'навыки переговоров',
#  'навыки презентации',
#  'сопровождение клиентов',
#  'телефонные переговоры',
#  'холодные звонки',
#  'оценка потребностей клиентов',
#  'управление отношениями клиентами',
#  'работа возражениями',
#  'поиск привлечение клиентов',
#  'высшее образование экономика математика статистика маркетинг продвинутый пользователь excel опыт построения аналитической отчетности желательно опыт работы bi системами навыки бюджетирования подготовки финансовой отчетности системное мышление',
#  'ms dynamics crm',
#  'crm',
#  'php',
#  'bitrix',
#  'территориальное месторасположение',
#  'гостиный двор',
#  'график работы',
#  'до',
#  'по пятницам до',
#  'конкурентоспособная заработная плата',
#  'расширенный социальный пакет полис дмс со стоматологией частичная компенсация годового абонемента спортивном клубе бесплатное питание',
#  'широкие возможности для профессионального карьерного роста',
#  '1с управление торговлей',
#  'git',
#  '1с документооборот',
#  '1с бухгалтерия',
#  '1с программирование знание типовых конфигураций управление торговлей',
#  'бухгалтерия предприятия',
#  'зарплата управление персоналом',
#  'знание механизмов интеграции 1с предприятия другими информационными системами web http odata знание скд бсп',
#  'опыт работы высоконагруженных проектах',
#  'понимание основ администрирования 1с',
#  'знание стандартов методик разработки конфигураций для платформы 1с предприятие',
#  'навыки командной разработки хранилище git',
#  'знание основ бюджетирования финансового планирования казначейства',
#  'высшее образование',
#  'опыт программирования ms dax любой версии от лет',
#  'английский язык на уровне чтения технической документации',
#  'будет плюсом опыт работы olap',
#  'asp',
#  'net',
#  'html',
#  'sql',
#  'net framework опыт коммерческой разработки по от 3х лет знание алгоритмов структур данных умение эти знания применять опыт разработки под dynamics crm знание объектной модели умение ей пользоваться отличное знание # asp',
#  'net javascript html css хорошее знание sql',
#  'высшее',
#  'образование вузы предпочтительные специальности прикладная математика радиофизика механико факультет информационные технологии компьютерные системы сети знание языков программирования базы данных abap sql умение читать код будет плюсом знание модулей sap логика работы настройки знание структуры понимание процессов crm erp опыт работы поддержке sap crm от лет опыт обучения пользователей сотрудников деловые личностные качества стрессоустойчивость честность обучаемость аналитическое системное мышление увлеченность делом дополнительные требования кандидату желательны хорошие знания предметной области лизинг банки страхование плюсом будут сертификаты по продуктам sap знание прочих crm erp',
#  'опыт настройки поддержки роли консультанта или старшего консультанта sap ehs',
#  'уровень владения английским языком не ниже intermediate',
#  'знание стандартных процессов области environment health and safety ehs',
#  'умение читать abap программы простой сложности debugging будет плюсом',
#  'hibernate orm',
#  'spring framework',
#  'java',
#  'postgresql',
#  'apache maven конкурентная заработная плата по результатам общения зависимости от рейта соблюдение tk рф уютный офис современная техника на рабочих местах гибкий рабочий график началом работы до дмс расширенным набором услуг чай кофе бонусы на др интересные нетривиальные задачи возможность посещать семинары тренинги конференции дружный коллектив профессионалов комфортная атмосфера возможность участия крупных интересных проектах',
#  'высшее техническое образование',
#  'опыт разработок на java от лет',
#  'знание принципов ооп',
#  'навык web react angular js',
#  'высшее образование',
#  'опыт работы - года роли ит аналитика ит консультанта опытом описания процессов проработки бизнес',
#  'знание стандартов babok обязательно terp10 - sap erp - интеграция бизнес желательно',
#  'опыт написания business recuirement document brd user stories us recuirements traceability matrix rtm',
#  'знание нотаций описания бизнес',
#  'опыт работы со специализированным по для описания бизнес',
#  'опыт работы jira confluence',
#  'знание общих принципов управления проектами управления изменениями области ит',
#  'высокие аналитические способности развитые коммуникативные навыки стрессоустойчивость',
#  'crm',
#  'работа команде',
#  'разработка инструкций',
#  'консультирование',
#  'информационные технологии',
#  'грамотная речь',
#  'обучение персонала',
#  'деловое общение',
#  'умение вести переговоры',
#  'пользователь пк',
#  'опыт продажах от года',
#  'умение работать на результат',
#  'холодные продажи',
#  '1с',
#  'ведение переговоров',
#  'поиск привлечение клиентов',
#  'заключение договоров',
#  'телефонные переговоры',
#  'crm',
#  'развитие продаж',
#  'подготовка презентаций',
#  'организация встреч уверенный пользователь пк опыт успешных продаж холодные теплые звонки опыт прямых успешных переговоров коммуникабельность знание теории продаж целеустремленность нацеленность на достижение результата',
#  'управление проектами',
#  'ms project',
#  'pmbok',
#  'английский язык',
#  'erp опыт разработки или внедрения сфере it',
#  'понимание потребностей бизнеса знание отраслевых особенностей',
#  'умение управлять проектами условиях неопределенности меняющихся требований',
#  'отличное знание основных методологий подходов области проектного управления разработки по',
#  'отличное владение русским языком способность структурировано четко выражать свои мысли как устно так письменно',
#  'опыт участия проектах внедрения erp систем опыт управления разработчикам владение стандартами методологией инструментами описания бизнес',
#  '1с программирование',
#  '1c бухгалтерия',
#  '1с предприятие',
#  '1с управление производственным предприятием',
#  'высшее техническое образование',
#  'знание angular',
#  'знания html css sass javascript es6 typescript',
#  'знание принципов ооп',
#  'опыт использования npm git',
#  'опыт работы со сборщиком webpack',
#  'навык web react angular js',
#  'navision',
#  'erp',
#  'erp systems',
#  'helpdesk',
#  'права доступа',
#  'ведение переговоров',
#  'активные продажи',
#  'деловое общение',
#  'навыки продаж',
#  'работа команде',
#  'деловая переписка',
#  'развитие продаж',
#  'управление продажами',
#  'грамотная речь',
#  'b2b продажи',
#  'прямые продажи',
#  'crm',
#  'английский a1 начальный ответственность внимательность большое желание расти развиваться быстрая обучаемость аналитический склад ума',
#  '1с зарплата управление персоналом',
#  '1с управление производственным предприятием',
#  '1с предприятие',
#  '1с производство',
#  '1с документооборот высшее техническое экономическое образование',
#  'опыт работы 1с',
#  'качестве разработчика не менее лет',
#  'знание архитектуры типовых конфигураций 1с упп документооборот бп зуп ух erp',
#  'наличие сертификатов по erp технологическим вопросам будет являться преимуществом',
#  'опыт работы от лет по реализации крупных проектов внедрения доработки упп документооборот бп зуп ух erp производственный учет управленческий учет планирование производства бухгалтерский учет зарплата управление персоналом логистика',
#  'знание предметных областей производственный учет бухгалтерский налоговый учет планирование производства',
#  'опыт разработки нового функционала корректировка имеющегося корпоративных информационных системах на базе 1с',
#  'умение быстро разбираться модифицировать чужой код',
#  'опыт работы конфигурацией 1с конвертация данных',
#  'опыт работы системой компоновки данных разработка сложных запросов',
#  'опыт работы распределенными базами данных',
#  'опыт работы по интеграции 1с различными внешними системами',
#  'опыт работы управляемыми формами',
#  'опыт разработки проектной документации',
#  'копирайтинг',
#  'английский язык',
#  'работа команде',
#  'написание текстов',
#  'написание статей',
#  'seo',
#  'проведение презентаций',
#  'обучение развитие',
#  'английский язык',
#  'тренинги',
#  'дистанционное обучение',
#  ...]

# %%
itmo_data = pd.read_csv('Data/Itmo_with_keywords_30.04.2020.csv', index_col=0)

# %%
itmo_data.head()
# Out:
#   SUBFIELDCODE                                      SUBFIELDNAME  \
# 0     09.03.01  Вычислительные машины, комплексы, системы и сети
# 1     09.03.01  Вычислительные машины, комплексы, системы и сети
# 2     09.03.01  Вычислительные машины, комплексы, системы и сети
# 3     09.03.01  Вычислительные машины, комплексы, системы и сети
# 4     09.03.01  Вычислительные машины, комплексы, системы и сети
#
#                    DEGREE       SUBJECT  SEMESTER  START_YEAR  \
# 0  Академический бакалавр    Математика         1        2014
# 1  Академический бакалавр    Математика         2        2014
# 2  Академический бакалавр        Физика         1        2014
# 3  Академический бакалавр        Физика         2        2014
# 4  Академический бакалавр  Основы права         1        2014
#
#                                             Keywords
# 0  Элементы линейной алгебры; Математический анал...
# 1  Элементы линейной алгебры; Математический анал...
# 2  Механика; Механические колебания и волны; Элем...
# 3  Механика; Механические колебания и волны; Элем...
# 4

# %% [markdown]
# # Prepating datasets

# %%
itmo_data['Keywords'] = itmo_data['Keywords'].apply(lambda x: x.lower())

# %%
itmo_data['Keywords'] = itmo_data['Keywords'].apply(lambda x: [phrase.strip() for phrase in re.split(r'[;,]', x)])
itmo_data['Keywords'] = itmo_data['Keywords'].apply(lambda x: [re.split(r'\bи\b', phrase) for phrase in x])

# %%
itmo_data['Keywords'] = itmo_data['Keywords'].apply(lambda x: [word for phrase in x for word in phrase])

# %%
en_lemmatizer = nltk.stem.WordNetLemmatizer()
ru_lemmatizer = pymorphy2.analyzer.MorphAnalyzer()

# %%
itmo_data['Keywords'] = itmo_data['Keywords'].apply(lambda x: 
                                                    [' '.join([en_lemmatizer.lemmatize(word) 
                                                               if re.search(r'[a-zA-Z]+', word) 
                                                               else ru_lemmatizer.parse(word)[0].normal_form
                                                               for word in phrase.split()]) 
                                                               for phrase in x])

# %%
for category in full_skills.index:
    full_skills[category] = [' '.join([en_lemmatizer.lemmatize(word) 
                                                               if re.search(r'[a-zA-Z]+', word) 
                                                               else ru_lemmatizer.parse(word)[0].normal_form
                                                               for word in phrase.split()]) 
                                                               for phrase in full_skills[category]]

# %%
itmo_data['Keywords'] = itmo_data['Keywords'].apply(lambda x: [re.sub(r'[():/«»]', ' ', phrase) for phrase in x])

# %%
itmo_data['SUBJECT'] = itmo_data['SUBJECT'].apply(lambda x : re.sub(r'[():/«»]', ' ', x))

# %%
itmo_data
# Out:
#       SUBFIELDCODE                                      SUBFIELDNAME  \
# 0         09.03.01  Вычислительные машины, комплексы, системы и сети
# 1         09.03.01  Вычислительные машины, комплексы, системы и сети
# 2         09.03.01  Вычислительные машины, комплексы, системы и сети
# 3         09.03.01  Вычислительные машины, комплексы, системы и сети
# 4         09.03.01  Вычислительные машины, комплексы, системы и сети
# ...            ...                                               ...
# 53108     27.03.04                       Цифровые системы управления
# 53109     27.03.04                       Цифровые системы управления
# 53110     11.04.02      Создание и эксплуатация сетей и систем связи
# 53111     11.04.02      Создание и эксплуатация сетей и систем связи
# 53112     38.03.02                               Управление проектом
#
#                        DEGREE  \
# 0      Академический бакалавр
# 1      Академический бакалавр
# 2      Академический бакалавр
# 3      Академический бакалавр
# 4      Академический бакалавр
# ...                       ...
# 53108  Академический бакалавр
# 53109  Академический бакалавр
# 53110                 Магистр
# 53111                 Магистр
# 53112  Академический бакалавр
#
#                                                  SUBJECT  SEMESTER  \
# 0                                             Математика         1
# 1                                             Математика         2
# 2                                                 Физика         1
# 3                                                 Физика         2
# 4                                           Основы права         1
# ...                                                  ...       ...
# 53108                  Линейная алгебра   Linear Algebra         1
# 53109                          Информатика   Informatics         1
# 53110  Методология управления проектами  Предпринимат...         1
# 53111         Личная эффективность и управление временем         1
# 53112                                  Бизнес английский         5
#
#        START_YEAR                                           Keywords
# 0            2014  [элемент линейный алгебра, математический анал...
# 1            2014  [элемент линейный алгебра, математический анал...
# 2            2014  [механик, механический колебание, волна, элеме...
# 3            2014  [механик, механический колебание, волна, элеме...
# 4            2014                                                 []
# ...           ...                                                ...
# 53108        2019                                                 []
# 53109        2019  [стандарт оформление научный документ, графиче...
# 53110        2019                                                 []
# 53111        2019  [  принцип, подход к оценка эффективность,   м...
# 53112        2017                                                 []
#
# [53113 rows x 7 columns]

# %%
vacancies_cat = []

for item in tqdm(itmo_data.values):
    vac_weights = []
    for name, vac in full_skills.items():
        vac_text = ' '.join(vac)    
        weight = 0
        for word in item[-1]:
            if word.strip() != '':
                if re.search(r'с\+\+', word):
                    weight += len(re.findall(r'с\+\+', vac_text))
                else:
                    weight += len(re.findall(word, vac_text))
                    
        if re.search(r'с\+\+', item[-4].lower()) or\
        item[-4].lower() == 'программирование на языках c, c++, java' or\
        re.search(r'c\+\+', item[-4].lower()):
            weight += len(re.findall(r'с\+\+', vac_text)) * 1.5
        else:
            weight += len(re.findall(item[-4].lower(), vac_text)) * 1.5
                    

        vac_weights.append((name, weight / (len(item[-1]) + len(vac))))
        
    if vac_weights != [] and vac_weights != None:
        vac_weights = sorted(vac_weights, key=lambda x: x[1], reverse=True)[0]
        if vac_weights[1] > 0:
            vacancies_cat.append(vac_weights[0])
        else:
            vacancies_cat.append(' ')
# Out:
# 100%|██████████| 53113/53113 [17:50<00:00, 49.61it/s]

# %%
itmo_data['vacancies_cat'] = vacancies_cat

# %%
stop_words = ['элемент', 'работа с библиотека', 'основа', 'общий концепция', 'теория', 'where to get', 'how to',
             'a', 'тема', 'общий', 'в', 'современный', 'о', 'цель', 'задача', 'содержание', 'основный',
             'раздел', 'введение в тип объект язык', 'с', 'что', 'такой', 'стандартный', 'особенность', 'язык',
             'введение', 'принцип', 'студент', 'main concept of ', 'к', 'на', 'применение', 'решение', 
             'пакет', 'они', 'возможность', 'основной', 'роль', 'more', 'on', ]

# %%
itmo_data['Keywords'] = itmo_data['Keywords'].apply(lambda x: [' '.join(word for word in phrase.split() if word not in stop_words) for phrase in x])

# %%
itmo_data.head()
# Out:
#   SUBFIELDCODE                                      SUBFIELDNAME  \
# 0     09.03.01  Вычислительные машины, комплексы, системы и сети
# 1     09.03.01  Вычислительные машины, комплексы, системы и сети
# 2     09.03.01  Вычислительные машины, комплексы, системы и сети
# 3     09.03.01  Вычислительные машины, комплексы, системы и сети
# 4     09.03.01  Вычислительные машины, комплексы, системы и сети
#
#                    DEGREE       SUBJECT  SEMESTER  START_YEAR  \
# 0  Академический бакалавр    Математика         1        2014
# 1  Академический бакалавр    Математика         2        2014
# 2  Академический бакалавр        Физика         1        2014
# 3  Академический бакалавр        Физика         2        2014
# 4  Академический бакалавр  Основы права         1        2014
#
#                                             Keywords  \
# 0  [линейный алгебра, математический анализ, функ...
# 1  [линейный алгебра, математический анализ, функ...
# 2  [механик, механический колебание, волна, специ...
# 3  [механик, механический колебание, волна, специ...
# 4                                                 []
#
#                            vacancies_cat
# 0                               аналитик
# 1                               аналитик
# 2  системы управления предприятием (erp)
# 3  системы управления предприятием (erp)
# 4

# %%
documents_hh = [TaggedDocument((' '.join(doc)).split(' '), [name]) for name,  doc in full_skills.items() if doc != []]
documents_itmo = [TaggedDocument((' '.join(doc)).split(' '), [' '.join((' '.join(doc)).split(' '))]) for doc in np.unique(itmo_data['Keywords']) if doc != []]

# %%
# constructing generic dataset
documents = documents_hh + documents_itmo

# %%
model = Doc2Vec(documents, dm=0, alpha=0.025, size=20, min_alpha=0.025, min_count=0)
# Out:
# /home/blakexdd/Documents/Github/Matching/venv/lib/python3.8/site-packages/gensim/models/doc2vec.py:574: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
for epoch in tqdm(range(100)):
    model.train(documents, total_examples=model.corpus_count, epochs=10)
    model.alpha -= 0.002
    model.min_alpha = model.alpha
# Out:
# 100%|██████████| 100/100 [01:05<00:00,  1.53it/s]

# %%
itmo_data.head()
# Out:
#   SUBFIELDCODE                                      SUBFIELDNAME  \
# 0     09.03.01  Вычислительные машины, комплексы, системы и сети
# 1     09.03.01  Вычислительные машины, комплексы, системы и сети
# 2     09.03.01  Вычислительные машины, комплексы, системы и сети
# 3     09.03.01  Вычислительные машины, комплексы, системы и сети
# 4     09.03.01  Вычислительные машины, комплексы, системы и сети
#
#                    DEGREE       SUBJECT  SEMESTER  START_YEAR  \
# 0  Академический бакалавр    Математика         1        2014
# 1  Академический бакалавр    Математика         2        2014
# 2  Академический бакалавр        Физика         1        2014
# 3  Академический бакалавр        Физика         2        2014
# 4  Академический бакалавр  Основы права         1        2014
#
#                                             Keywords  \
# 0  [линейный алгебра, математический анализ, функ...
# 1  [линейный алгебра, математический анализ, функ...
# 2  [механик, механический колебание, волна, специ...
# 3  [механик, механический колебание, волна, специ...
# 4                                                 []
#
#                            vacancies_cat
# 0                               аналитик
# 1                               аналитик
# 2  системы управления предприятием (erp)
# 3  системы управления предприятием (erp)
# 4

# %%
vac = []

for desc in tqdm(itmo_data.values):
    most_sim = 0
    vacn = ' '
    
    if desc[-1] == ' ':
        desc_sim = []
        for name, vacancy in full_skills.items():
            sim = model.docvecs.similarity(' '.join(desc[-2]), name)
            desc_sim.append((desc[3], sim, name))

        vac.append(sorted(desc_sim, key=lambda x:x[1], reverse=True)[0][-1])
    else:
        vac.append(' ')
# Out:
# 100%|██████████| 53113/53113 [00:05<00:00, 9972.10it/s]

# %%
itmo_data['vacancies_cat'] = itmo_data['vacancies_cat'] + vac

# %%
itmo_data[:50]
# Out:
#    SUBFIELDCODE                                       SUBFIELDNAME  \
# 0      09.03.01   Вычислительные машины, комплексы, системы и сети
# 1      09.03.01   Вычислительные машины, комплексы, системы и сети
# 2      09.03.01   Вычислительные машины, комплексы, системы и сети
# 3      09.03.01   Вычислительные машины, комплексы, системы и сети
# 4      09.03.01   Вычислительные машины, комплексы, системы и сети
# 5      09.03.01   Вычислительные машины, комплексы, системы и сети
# 6      09.03.01   Вычислительные машины, комплексы, системы и сети
# 7      09.03.01   Вычислительные машины, комплексы, системы и сети
# 8      09.03.01   Вычислительные машины, комплексы, системы и сети
# 9      09.03.01   Вычислительные машины, комплексы, системы и сети
# 10     09.03.01   Вычислительные машины, комплексы, системы и сети
# 11     09.03.01   Вычислительные машины, комплексы, системы и сети
# 12     09.03.01   Вычислительные машины, комплексы, системы и сети
# 13     09.03.01   Вычислительные машины, комплексы, системы и сети
# 14     09.03.01   Вычислительные машины, комплексы, системы и сети
# 15     09.03.01   Вычислительные машины, комплексы, системы и сети
# 16     09.03.01   Вычислительные машины, комплексы, системы и сети
# 17     09.03.01   Вычислительные машины, комплексы, системы и сети
# 18     09.03.02  Автоматизация и управление в образовательных с...
# 19     09.03.02  Автоматизация и управление в образовательных с...
# 20     09.03.02  Автоматизация и управление в образовательных с...
# 21     09.03.02  Автоматизация и управление в образовательных с...
# 22     09.03.02  Автоматизация и управление в образовательных с...
# 23     09.03.02  Автоматизация и управление в образовательных с...
# 24     09.03.02  Автоматизация и управление в образовательных с...
# 25     09.03.02  Автоматизация и управление в образовательных с...
# 26     09.03.02  Автоматизация и управление в образовательных с...
# 27     09.03.02  Автоматизация и управление в образовательных с...
# 28     09.03.02  Автоматизация и управление в образовательных с...
# 29     09.03.02  Автоматизация и управление в образовательных с...
# 30     09.03.02  Автоматизация и управление в образовательных с...
# 31     09.03.02  Автоматизация и управление в образовательных с...
# 32     09.03.02  Автоматизация и управление в образовательных с...
# 33     09.03.02  Автоматизация и управление в образовательных с...
# 34     09.03.02  Автоматизация и управление в образовательных с...
# 35     09.03.04        Разработка программно-информационных систем
# 36     09.03.04        Разработка программно-информационных систем
# 37     09.03.04        Разработка программно-информационных систем
# 38     09.03.04        Разработка программно-информационных систем
# 39     09.03.04        Разработка программно-информационных систем
# 40     09.03.04        Разработка программно-информационных систем
# 41     09.03.04        Разработка программно-информационных систем
# 42     09.03.04        Разработка программно-информационных систем
# 43     09.03.04        Разработка программно-информационных систем
# 44     09.03.04        Разработка программно-информационных систем
# 45     09.03.04        Разработка программно-информационных систем
# 46     09.03.04        Разработка программно-информационных систем
# 47     09.03.04        Разработка программно-информационных систем
# 48     09.03.04        Разработка программно-информационных систем
# 49     09.03.04        Разработка программно-информационных систем
#
#                     DEGREE                                     SUBJECT  \
# 0   Академический бакалавр                                  Математика
# 1   Академический бакалавр                                  Математика
# 2   Академический бакалавр                                      Физика
# 3   Академический бакалавр                                      Физика
# 4   Академический бакалавр                                Основы права
# 5   Академический бакалавр                     Основы программирования
# 6   Академический бакалавр                     Основы программирования
# 7   Академический бакалавр               Основы вычислительной техники
# 8   Академический бакалавр               Основы вычислительной техники
# 9   Академический бакалавр                         Физическая культура
# 10  Академический бакалавр                         Физическая культура
# 11  Академический бакалавр                            Иностранный язык
# 12  Академический бакалавр                            Иностранный язык
# 13  Академический бакалавр                       Дискретная математика
# 14  Академический бакалавр   Математическая логика и теория алгоритмов
# 15  Академический бакалавр                     Компьютерная математика
# 16  Академический бакалавр                               Культурология
# 17  Академический бакалавр                                    Риторика
# 18  Академический бакалавр  Организация и управление бизнес-процессами
# 19  Академический бакалавр   Объектно-ориентированное программирование
# 20  Академический бакалавр                Структура данных и алгоритмы
# 21  Академический бакалавр                        Компьютерная графика
# 22  Академический бакалавр                            Иностранный язык
# 23  Академический бакалавр                            Иностранный язык
# 24  Академический бакалавр                               Культурология
# 25  Академический бакалавр  Имидж специалиста и корпоративная культура
# 26  Академический бакалавр                                  Математика
# 27  Академический бакалавр                                  Математика
# 28  Академический бакалавр                                      Физика
# 29  Академический бакалавр                                      Физика
# 30  Академический бакалавр                     Основы программирования
# 31  Академический бакалавр                    Введение в специальность
# 32  Академический бакалавр             Основы эффективных коммуникаций
# 33  Академический бакалавр                         Физическая культура
# 34  Академический бакалавр                         Физическая культура
# 35  Академический бакалавр                       Дискретная математика
# 36  Академический бакалавр                     Комбинаторные алгоритмы
# 37  Академический бакалавр   Математическая логика и теория алгоритмов
# 38  Академический бакалавр                               Культурология
# 39  Академический бакалавр                                    Риторика
# 40  Академический бакалавр                                  Математика
# 41  Академический бакалавр                                  Математика
# 42  Академический бакалавр                                      Физика
# 43  Академический бакалавр                                      Физика
# 44  Академический бакалавр                                Основы права
# 45  Академический бакалавр                     Основы программирования
# 46  Академический бакалавр                     Основы программирования
# 47  Академический бакалавр                         Физическая культура
# 48  Академический бакалавр                         Физическая культура
# 49  Академический бакалавр                            Иностранный язык
#
#     SEMESTER  START_YEAR                                           Keywords  \
# 0          1        2014  [линейный алгебра, математический анализ, функ...
# 1          2        2014  [линейный алгебра, математический анализ, функ...
# 2          1        2014  [механик, механический колебание, волна, специ...
# 3          2        2014  [механик, механический колебание, волна, специ...
# 4          1        2014                                                 []
# 5          1        2014  [программирование, парадигма программирование,...
# 6          2        2014  [программирование, парадигма программирование,...
# 7          1        2014  [, построение эвм, архитектура персональный ко...
# 8          2        2014  [, построение эвм, архитектура персональный ко...
# 9          1        2014  [здоровый образ жизнь, спорт, физиологический,...
# 10         2        2014  [здоровый образ жизнь, спорт, физиологический,...
# 11         1        2014  [личность, описание внешность, физический хара...
# 12         2        2014  [личность, описание внешность, физический хара...
# 13         2        2014  [конструктивно-исследовательский, сочетание, к...
# 14         2        2014  [множество, вычислимость, булев функция, форма...
# 15         2        2014  [mathematica, выражение, преобразование, вычис...
# 16         1        2014  [диффузионизм, проблема смысл, типология знак,...
# 17         1        2014                                                 []
# 18         2        2014  [функциональный, процессный подход управление ...
# 19         2        2014  [объектно-ориентированный программирование, би...
# 20         2        2014  [mergesort, recurrence, and asymptotics, solvi...
# 21         2        2014  [физический компьютерный графика, понятие комп...
# 22         1        2014  [личность, описание внешность, физический хара...
# 23         2        2014  [личность, описание внешность, физический хара...
# 24         1        2014  [диффузионизм, проблема смысл, типология знак,...
# 25         1        2014  [internal communication, corporate branding, c...
# 26         1        2014  [линейный алгебра, математический анализ, функ...
# 27         2        2014  [линейный алгебра, математический анализ, функ...
# 28         1        2014  [механик, механический колебание, волна, специ...
# 29         2        2014  [механик, механический колебание, волна, специ...
# 30         1        2014  [программирование, парадигма программирование,...
# 31         1        2014  [main concept of modern phonetics, main concep...
# 32         1        2014  [курс – деловой коммуникация, практический сре...
# 33         1        2014  [здоровый образ жизнь, спорт, физиологический,...
# 34         2        2014  [здоровый образ жизнь, спорт, физиологический,...
# 35         2        2014  [конструктивно-исследовательский, сочетание, к...
# 36         2        2014                                                 []
# 37         2        2014  [множество, вычислимость, булев функция, форма...
# 38         1        2014  [диффузионизм, проблема смысл, типология знак,...
# 39         1        2014                                                 []
# 40         1        2014  [линейный алгебра, математический анализ, функ...
# 41         2        2014  [линейный алгебра, математический анализ, функ...
# 42         1        2014  [механик, механический колебание, волна, специ...
# 43         2        2014  [механик, механический колебание, волна, специ...
# 44         1        2014                                                 []
# 45         1        2014  [программирование, парадигма программирование,...
# 46         2        2014  [программирование, парадигма программирование,...
# 47         1        2014  [здоровый образ жизнь, спорт, физиологический,...
# 48         2        2014  [здоровый образ жизнь, спорт, физиологический,...
# 49         1        2014  [личность, описание внешность, физический хара...
#
#                              vacancies_cat
# 0                                аналитик
# 1                                аналитик
# 2   системы управления предприятием (erp)
# 3   системы управления предприятием (erp)
# 4                                  инженер
# 5                cto, cio, директор по it
# 6                cto, cio, директор по it
# 7                                интернет
# 8                                интернет
# 9                cto, cio, директор по it
# 10               cto, cio, директор по it
# 11                              маркетинг
# 12                              маркетинг
# 13                                продажи
# 14                        телекоммуникации
# 15                системный администратор
# 16               cto, cio, директор по it
# 17                                 инженер
# 18                               аналитик
# 19               администратор баз данных
# 20                    поддержка, helpdesk
# 21                   системная интеграция
# 22                              маркетинг
# 23                              маркетинг
# 24               cto, cio, директор по it
# 25                     поддержка, helpdesk
# 26                               аналитик
# 27                               аналитик
# 28  системы управления предприятием (erp)
# 29  системы управления предприятием (erp)
# 30               cto, cio, директор по it
# 31                             web инженер
# 32                                продажи
# 33               cto, cio, директор по it
# 34               cto, cio, директор по it
# 35                                продажи
# 36                                 инженер
# 37                        телекоммуникации
# 38               cto, cio, директор по it
# 39                                 инженер
# 40                               аналитик
# 41                               аналитик
# 42  системы управления предприятием (erp)
# 43  системы управления предприятием (erp)
# 44                                 инженер
# 45               cto, cio, директор по it
# 46               cto, cio, директор по it
# 47               cto, cio, директор по it
# 48               cto, cio, директор по it
# 49                              маркетинг

# %%
itmo_data.to_csv('Data/itmo_with_vacancies_11_may_2020.csv')

# %%
itmo_data['SUBJECT'].unique().shape
# Out:
# (6928,)
